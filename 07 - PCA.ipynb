# %% [markdown]
# # Análise de Componentes Principais (PCA)
#
# O PCA procura um novo sistema de coordenadas para os dados em que os eixos apontam nas direções de maior variância e são ortogonais entre si. Como a variância se concentra nos primeiros eixos, descartar os últimos custa pouca informação, e é assim que a técnica reduz dimensionalidade. Neste notebook derivamos o método a partir da matriz de covariância, implementamos a classe do zero e aplicamos a dados de quatro e de mil oitocentas dimensões.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_lfw_people, load_iris
from sklearn.decomposition import PCA as SklearnPCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

plt.style.use('seaborn-v0_8-whitegrid')
rng = np.random.default_rng(42)
# %matplotlib inline

# %% [markdown]
# ## Dataset Sintético
#
# Começamos com 100 pontos em 2D dispostos em torno de uma reta de inclinação 2, com ruído gaussiano. As duas coordenadas são fortemente correlacionadas: sabendo a primeira, quase sabemos a segunda. É exatamente essa redundância que o PCA vai explorar.

# %%
x1 = rng.uniform(0, 10, 100)
x2 = 2 * x1 + 3 + rng.normal(0, 2, 100)
X = np.c_[x1, x2]

plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], alpha=0.7)
plt.title('Dataset Sintético')
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Fundamentação Matemática
#
# ### Covariância
#
# A covariância mede a relação linear entre duas variáveis: é positiva quando elas crescem juntas, negativa quando uma cresce enquanto a outra diminui, e próxima de zero quando não há tendência linear. Para $m$ amostras,
#
# $$ \text{cov}(X, Y) = \frac{1}{m-1}\sum_{i=1}^{m} (x_i - \bar{x})(y_i - \bar{y}) $$
#
# Com $n$ características, a **matriz de covariância** $\Sigma \in \mathbb{R}^{n \times n}$ reúne todas as combinações:
#
# $$
# \Sigma = \begin{pmatrix}
# \text{cov}(X_1, X_1) & \cdots & \text{cov}(X_1, X_n) \\
# \vdots & \ddots & \vdots \\
# \text{cov}(X_n, X_1) & \cdots & \text{cov}(X_n, X_n)
# \end{pmatrix}
# $$
#
# A diagonal traz as variâncias de cada característica, já que $\text{cov}(X_j, X_j) = \text{var}(X_j)$, e a matriz é simétrica porque $\text{cov}(X_i, X_j) = \text{cov}(X_j, X_i)$.
#
# Antes de calculá-la, é preciso **centralizar** os dados subtraindo a média de cada coluna. Sem isso, as direções encontradas passariam a descrever a posição da nuvem em relação à origem, e não o seu formato.

# %%
mean = X.mean(axis=0)
X_centered = X - mean

cov_matrix = np.cov(X_centered, rowvar=False)   # rowvar=False: as colunas são as variáveis

print(f"Média das características: {mean}")
print(f"\nMatriz de covariância:\n{cov_matrix}")

# %% [markdown]
# ### Autovetores e Autovalores
#
# Um **autovetor** de uma matriz é um vetor não nulo cuja direção não muda quando a matriz é aplicada a ele. Apenas o comprimento muda, por um fator $\lambda$ chamado **autovalor**:
#
# $$ \Sigma v = \lambda v $$
#
# Para a matriz de covariância, essa decomposição tem uma leitura direta. Os autovetores são as direções em que os dados variam de forma independente, ou seja, os **componentes principais**, e a simetria de $\Sigma$ garante que sejam ortogonais entre si. Já os autovalores são a variância dos dados ao longo de cada uma dessas direções.
#
# Ordenando os autovalores em ordem decrescente, o primeiro componente principal é a direção de maior variância, o segundo é a direção de maior variância entre as perpendiculares à primeira, e assim por diante.
#
# Usamos `np.linalg.eigh`, e não `np.linalg.eig`, porque a matriz de covariância é simétrica: a versão especializada é mais rápida e garante autovalores reais e autovetores ortonormais.

# %%
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

# eigh devolve em ordem crescente; queremos o maior autovalor primeiro
order = eigenvalues.argsort()[::-1]
eigenvalues = eigenvalues[order]
eigenvectors = eigenvectors[:, order]      # cada coluna é um autovetor

print(f"Autovalores: {eigenvalues}")
print(f"\nAutovetores (um por coluna):\n{eigenvectors}")

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)

for i in range(len(eigenvalues)):
    # o vetor é escalado por 2 desvios padrão para ficar visível na escala dos dados
    vector = eigenvectors[:, i] * np.sqrt(eigenvalues[i]) * 2
    plt.quiver(mean[0], mean[1], vector[0], vector[1], angles='xy', scale_units='xy',
               scale=1, color='red', width=0.006)
    plt.annotate(f'PC{i + 1}', mean + vector * 1.1, color='red', fontsize=13)

plt.title('Componentes Principais dos Dados')
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.axis('equal')
plt.show()

# %% [markdown]
# O PC1 acompanha a reta em torno da qual os dados foram gerados, e o PC2 é perpendicular a ele, medindo apenas a espessura da nuvem. Os autovalores quantificam a diferença: 41,06 contra 0,71. Ou seja, o novo eixo mais importante concentra quase toda a variação, e o segundo é praticamente só o ruído que adicionamos.
#
# Repare que o PC1 **não** é a reta de regressão. A regressão minimiza os erros verticais, na direção de $y$; o PC1 minimiza as distâncias perpendiculares à própria reta, tratando as duas variáveis simetricamente.

# %% [markdown]
# ### Variância Explicada
#
# Como cada autovalor é a variância ao longo de um componente, e a soma deles é a variância total dos dados, a fração da informação capturada por cada componente é imediata:
#
# $$ \text{razão de variância explicada}_k = \frac{\lambda_k}{\sum_{j} \lambda_j} $$
#
# Esse é o número que decide quantos componentes reter.

# %%
explained_variance_ratio = eigenvalues / eigenvalues.sum()

for i, ratio in enumerate(explained_variance_ratio):
    print(f"PC{i + 1}: {ratio:.2%} da variância  (autovalor = {eigenvalues[i]:.3f})")

# %% [markdown]
# O PC1 sozinho carrega 98,3% da variância. Projetar esses dados de 2 para 1 dimensão descarta 1,7% da informação, o que, neste caso, é quase exatamente o ruído.

# %% [markdown]
# ## Implementação
#
# A classe reúne os passos acima e segue a interface do Scikit-Learn: `fit`, `transform`, `fit_transform` e `inverse_transform`, esta última para voltar do espaço reduzido ao original.

# %%
class PCA:
    def __init__(self, n_components):
        self.n_components = n_components
        self.mean = None
        self.components = None                  # (n_components, n_features), um componente por linha
        self.explained_variance = None
        self.explained_variance_ratio = None

    def fit(self, X):
        self.mean = X.mean(axis=0)
        X_centered = X - self.mean

        cov_matrix = np.cov(X_centered, rowvar=False)
        eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

        order = eigenvalues.argsort()[::-1]
        eigenvalues = eigenvalues[order]
        eigenvectors = eigenvectors[:, order]

        self.components = eigenvectors[:, :self.n_components].T
        self.explained_variance = eigenvalues[:self.n_components]
        self.explained_variance_ratio = self.explained_variance / eigenvalues.sum()

        return self

    def transform(self, X):
        """Projeta os dados no espaço dos componentes principais."""
        return (X - self.mean) @ self.components.T

    def fit_transform(self, X):
        return self.fit(X).transform(X)

    def inverse_transform(self, X_projected):
        """Reconstrói uma aproximação dos dados originais a partir da projeção."""
        return X_projected @ self.components + self.mean

# %%
pca = PCA(n_components=1)
X_projected = pca.fit_transform(X)
X_reconstructed = pca.inverse_transform(X_projected)

print(f"Original:      {X.shape}")
print(f"Projetado:     {X_projected.shape}")
print(f"Reconstruído:  {X_reconstructed.shape}")
# erro quadrático por amostra, somando sobre as features
reconstruction_error = np.mean(np.sum((X - X_reconstructed) ** 2, axis=1))

print(f"\nErro quadrático de reconstrução: {reconstruction_error:.4f}")
print(f"Segundo autovalor, descartado:   {eigenvalues[1]:.4f}")

# %% [markdown]
# Os dois últimos números são quase o mesmo, e isso não é coincidência: o erro quadrático médio de reconstrução do PCA é exatamente a soma dos autovalores descartados (a menos do fator $\frac{m-1}{m}$ entre as duas convenções de variância). Descartar um componente custa precisamente a variância que ele carregava, e é essa identidade que torna a razão de variância explicada um critério confiável.

# %% [markdown]
# ### Comparação com o Scikit-Learn
#
# ```python
# from sklearn.decomposition import PCA
#
# pca = PCA(n_components=2).fit(X)
# pca.transform(X)                  # projeção
# pca.components_                   # componentes, um por linha
# pca.explained_variance_ratio_     # fração da variância por componente
# pca.inverse_transform(Z)          # reconstrução
# ```
#
# A implementação do Scikit-Learn não diagonaliza a matriz de covariância: ela aplica a **decomposição em valores singulares (SVD)** diretamente sobre os dados centralizados. O resultado é matematicamente o mesmo, mas numericamente mais estável, porque calcular $\Sigma = \frac{1}{m-1} X^\top X$ eleva ao quadrado o condicionamento do problema e perde precisão quando as escalas das features são muito diferentes.

# %% [markdown]
# ## Aplicação: Iris
#
# O Iris tem 4 características, o que impede a visualização direta. Vamos projetá-lo em 2 dimensões.
#
# O PCA é sensível à escala: como ele busca direções de máxima variância, uma característica medida numa unidade de maior magnitude domina os componentes só por causa da unidade. Padronizar antes, com média zero e desvio unitário, coloca todas em pé de igualdade.

# %%
iris = load_iris()
X_iris = StandardScaler().fit_transform(iris.data)
y_iris = iris.target

pca_iris = PCA(n_components=4).fit(X_iris)

for i, ratio in enumerate(pca_iris.explained_variance_ratio):
    print(f"PC{i + 1}: {ratio:6.2%}   acumulado: {pca_iris.explained_variance_ratio[:i + 1].sum():6.2%}")

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
components = np.arange(1, 5)

axes[0].bar(components, pca_iris.explained_variance_ratio, color='steelblue')
axes[0].set_title('Variância Explicada por Componente')
axes[0].set_xlabel('Componente')
axes[0].set_ylabel('Fração da variância')
axes[0].set_xticks(components)

axes[1].plot(components, np.cumsum(pca_iris.explained_variance_ratio), 'o-', color='indigo')
axes[1].axhline(0.95, color='red', linestyle='--', label='95%')
axes[1].set_title('Variância Explicada Acumulada')
axes[1].set_xlabel('Número de componentes')
axes[1].set_ylabel('Fração acumulada')
axes[1].set_xticks(components)
axes[1].set_ylim(0, 1.05)
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Esse gráfico de barras decrescentes é o **scree plot**, e é a ferramenta usual para escolher o número de componentes. Aqui os dois primeiros componentes acumulam 95,8% da variância: passar de 4 para 2 dimensões custa 4,2% da informação. O terceiro e o quarto componentes carregam 3,7% e 0,5%, o que sugere que o Iris é, essencialmente, um conjunto de dados bidimensional descrito com quatro medições redundantes.

# %%
X_iris_pca = PCA(n_components=2).fit_transform(X_iris)

plt.figure(figsize=(10, 7))

for i, (color, name) in enumerate(zip(['navy', 'turquoise', 'darkorange'], iris.target_names)):
    mask = y_iris == i
    plt.scatter(X_iris_pca[mask, 0], X_iris_pca[mask, 1], color=color, alpha=0.8, label=name)

plt.title('Iris Projetado nos Dois Primeiros Componentes Principais')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend()
plt.show()

# %% [markdown]
# As três espécies aparecem bem organizadas ao longo do PC1: a setosa fica isolada à esquerda, e versicolor e virginica se sucedem à direita, com alguma sobreposição na fronteira.
#
# Vale insistir num ponto: o PCA **não usou os rótulos**. Ele apenas procurou as direções de maior variância, e a separação entre espécies emergiu como subproduto. Isso acontece porque, neste conjunto, a maior fonte de variação entre as flores é justamente aquilo que distingue as espécies, o que não é garantido em geral. Nada impede que a direção de maior variância de um conjunto seja iluminação, ruído de medição ou qualquer outro fator irrelevante para a estrutura que interessa.
#
# Os **loadings** (os pesos de cada característica original em cada componente) explicam o que os eixos significam.

# %%
loadings = PCA(n_components=2).fit(X_iris).components

print(f"{'característica':22} {'PC1':>8} {'PC2':>8}")
for name, pc1, pc2 in zip(iris.feature_names, loadings[0], loadings[1]):
    print(f"{name:22} {pc1:8.3f} {pc2:8.3f}")

# %% [markdown]
# O PC1 recebe pesos de magnitude parecida das duas medidas de pétala e do comprimento da sépala, com sinal oposto ao da largura da sépala: é um eixo de **tamanho geral da flor**, puxado principalmente pelas pétalas. Já o PC2 é quase inteiramente a largura da sépala (peso 0,92 contra menos de 0,4 nas demais), a única medida que não acompanha as outras, e por isso sobrou para o segundo eixo.
#
# O sinal dos componentes é arbitrário: $v$ e $-v$ descrevem a mesma direção e são igualmente válidos como autovetores. Se você comparar esses loadings com os do Scikit-Learn, é normal que o PC1 apareça com todos os sinais trocados. O que precisa coincidir são as magnitudes e as posições relativas dos pontos projetados, não a orientação dos eixos.

# %% [markdown]
# ## Aplicação: Eigenfaces
#
# A aplicação clássica do PCA em visão computacional trata cada imagem como um vetor em que cada pixel é uma dimensão. Rostos alinhados ocupam uma região minúscula desse espaço, já que a esmagadora maioria dos vetores de 1850 pixels é ruído visual e não um rosto, e o PCA encontra o subespaço onde eles de fato vivem.
#
# Os componentes principais, remodelados de volta ao formato de imagem, são as **eigenfaces**: os "ingredientes" a partir dos quais qualquer rosto do conjunto pode ser recomposto por combinação linear.
#
# Usamos o *Labeled Faces in the Wild*, restrito às pessoas com pelo menos 70 fotos. O download é feito uma única vez e fica em cache.

# %%
lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

n_samples, h, w = lfw_people.images.shape
X_faces = lfw_people.data
y_faces = lfw_people.target
target_names = lfw_people.target_names

print(f"Amostras: {n_samples}")
print(f"Pixels por imagem: {X_faces.shape[1]} ({h} x {w})")
print(f"Pessoas distintas: {len(target_names)}")

# %%
def plot_gallery(images, titles, h, w, n_row=3, n_col=4):
    """Mostra uma grade de imagens a partir dos vetores de pixels."""
    plt.figure(figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)

    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
        plt.title(titles[i], size=12)
        plt.xticks(())
        plt.yticks(())

    plt.show()


plot_gallery(X_faces, [target_names[y] for y in y_faces[:12]], h, w)

# %% [markdown]
# ### Ajustando o PCA
#
# Separamos treino e teste e ajustamos o PCA **apenas no treino**. Isso importa: se os componentes fossem calculados sobre o conjunto todo, os rostos de teste teriam participado da definição do subespaço em que serão avaliados, e a qualidade da reconstrução ficaria otimista.
#
# Vamos reter 150 componentes, contra os 1850 pixels originais.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_faces, y_faces, test_size=0.25, random_state=42)

pca_faces = PCA(n_components=150).fit(X_train)

print(f"{X_train.shape[1]} pixels → 150 componentes")
print(f"Variância explicada pelos 150 componentes: {pca_faces.explained_variance_ratio.sum():.2%}")

# %%
eigenfaces = pca_faces.components.reshape((150, h, w))

plot_gallery(eigenfaces, [f'eigenface {i}' for i in range(12)], h, w)

# %% [markdown]
# As primeiras eigenfaces não se parecem com pessoas específicas, e sim com padrões de variação. As de menor índice costumam capturar iluminação, com um lado do rosto claro e o outro escuro, que é a maior fonte de variação em fotos não controladas; as seguintes passam a codificar contorno do rosto, posição dos olhos e da boca. Quanto maior o índice, mais alta a frequência espacial e menor a variância associada.
#
# Vale notar o que isso implica: a direção de maior variância de um conjunto de fotos é a iluminação, não a identidade. O PCA otimiza variância, e variância não é o mesmo que informação útil.

# %% [markdown]
# ### Reconstrução
#
# Projetar um rosto no subespaço reduz 1850 números a 150 pesos, um por eigenface. A reconstrução é a combinação linear das eigenfaces com esses pesos, somada ao rosto médio.

# %%
X_test_projected = pca_faces.transform(X_test)
X_test_reconstructed = pca_faces.inverse_transform(X_test_projected)

n_comparisons = 5
fig, axes = plt.subplots(2, n_comparisons, figsize=(2.2 * n_comparisons, 5.5))

for i in range(n_comparisons):
    axes[0, i].imshow(X_test[i].reshape((h, w)), cmap=plt.cm.gray)
    axes[0, i].set_title(target_names[y_test[i]].split()[-1], size=11)
    axes[1, i].imshow(X_test_reconstructed[i].reshape((h, w)), cmap=plt.cm.gray)

    for ax in (axes[0, i], axes[1, i]):
        ax.set_xticks(())
        ax.set_yticks(())

axes[0, 0].set_ylabel('Original', size=12)
axes[1, 0].set_ylabel('Reconstruído', size=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# Os rostos reconstruídos são reconhecíveis, ainda que suavizados: o PCA preserva o que é comum a muitos rostos e descarta o que é idiossincrático de cada um. Detalhes de textura, fios de cabelo e o fundo, tudo que varia de forma pouco correlacionada entre as imagens, ficam nos componentes descartados.
#
# Vale medir a troca entre compressão e fidelidade de forma quantitativa.

# %%
print(f"{'componentes':>12} {'variância explicada':>20} {'erro de reconstrução':>22} {'compressão':>12}")

for k in [5, 20, 50, 150, 400]:
    model = PCA(n_components=k).fit(X_train)
    reconstructed = model.inverse_transform(model.transform(X_test))

    error = np.mean((X_test - reconstructed) ** 2)
    print(f"{k:>12} {model.explained_variance_ratio.sum():>19.2%} "
          f"{error:>22.4f} {X_train.shape[1] / k:>11.1f}x")

# %% [markdown]
# A curva é fortemente decrescente: os primeiros componentes compram muita fidelidade, e os últimos, quase nenhuma. É a mesma assinatura do scree plot do Iris, e a razão de o PCA funcionar como compressor, porque em dados reais a variância quase nunca está distribuída uniformemente pelas dimensões.

# %% [markdown]
# ## Custo e Limitações
#
# Montar a matriz de covariância é $O(m n^2)$ e diagonalizá-la, $O(n^3)$, com $n$ features e $m$ amostras. Para os 1850 pixels do LFW isso é tranquilo; para dados com centenas de milhares de features, a matriz de covariância sequer cabe na memória, e é preciso recorrer à SVD truncada (`svd_solver='randomized'`) ou ao `IncrementalPCA`, que processa os dados em lotes.
#
# A limitação de fundo é que o PCA só captura estrutura linear, porque procura um subespaço plano. Dados que vivem sobre uma superfície curva, como uma espiral ou um rolo suíço, não são desdobrados por nenhuma projeção linear, e é justamente esse limite que motiva os métodos não lineares.
#
# Além disso, variância não é sinônimo de informação. O critério do PCA é a variância, e nada garante que a direção de maior variância seja a mais relevante. As eigenfaces deixam isso explícito ao gastar os primeiros componentes com iluminação. Se a estrutura que interessa tem baixa variância, o PCA a descarta primeiro.
#
# Três ressalvas práticas fecham a lista. O método é sensível à escala, e sem padronização a característica de maior magnitude domina os componentes; a padronização, por sua vez, é uma decisão e não um automatismo, porque declara que todas as características importam igualmente. Os componentes são difíceis de interpretar, já que cada um é uma combinação de *todas* as características originais: no Iris, com 4 medidas, os loadings ainda se leem, mas com mil o componente vira um objeto sem significado direto. E o PCA é sensível a outliers, porque a variância envolve desvios ao quadrado e um punhado de pontos extremos pode girar os componentes sozinho.

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercício 1: Visualização do Dataset Wine
#
# O dataset `wine` traz 13 medidas químicas de vinhos de três cultivares da mesma região da Itália. Padronize as 13 características, aplique o PCA e projete os dados em 2 componentes, colorindo cada ponto pelo cultivar.
#
# Quanto da variância os dois primeiros componentes retêm? Compare com os 95,8% do Iris e explique a diferença a partir do scree plot dos 13 componentes. Em seguida, examine os loadings do PC1: quais medidas químicas o dominam?

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 2: Compressão do MNIST
#
# Carregue o MNIST (por exemplo com `sklearn.datasets.fetch_openml('mnist_784')`), que traz dígitos manuscritos de 28×28 pixels, e repita a análise das eigenfaces: ajuste o PCA no conjunto de treino e reconstrua imagens do teste com 2, 10, 50 e 200 componentes.
#
# Determine quantos componentes são necessários para reter 90% da variância e compare esse número com os 784 pixels originais. Depois, projete o conjunto em 2 dimensões e colora os pontos pelo dígito: quais dígitos se sobrepõem, e por quê?

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 3: O Limite Linear
#
# Gere pontos sobre um rolo suíço com `sklearn.datasets.make_swiss_roll`, uma superfície bidimensional enrolada dentro de $\mathbb{R}^3$, e aplique o PCA para reduzir a 2 dimensões, colorindo os pontos pela posição ao longo do rolo.
#
# O PCA consegue desenrolar a superfície? Explique o que ele faz com ela e por que nenhuma escolha de componentes resolveria o problema. Verifique também qual é a variância explicada pelos 2 primeiros componentes, que é alta, e isso deveria bastar como aviso sobre confiar apenas nesse número.

# %%
# Seu código aqui
