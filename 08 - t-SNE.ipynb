# %% [markdown]
# # t-Distributed Stochastic Neighbor Embedding (t-SNE)
#
# O t-SNE é uma técnica de redução de dimensionalidade não linear voltada para visualização. Enquanto o PCA procura as direções de maior variância e preserva a estrutura global dos dados, o t-SNE abandona qualquer compromisso com distâncias globais e otimiza uma coisa só: que pontos próximos no espaço original continuem próximos no mapa de duas dimensões. Essa escolha é o que permite ao t-SNE revelar agrupamentos que projeções lineares deixam sobrepostos, e é também a origem das suas armadilhas de interpretação.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
from sklearn.datasets import make_blobs, load_digits
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE as SklearnTSNE
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

# %% [markdown]
# ## Fundamentação Matemática
#
# O t-SNE trabalha com duas distribuições de probabilidade sobre pares de pontos: uma no espaço original, chamada $P$, e outra no mapa de baixa dimensão, chamada $Q$. O algoritmo move os pontos do mapa até que $Q$ se pareça o máximo possível com $P$.
#
# ### Similaridades no Espaço Original
#
# A similaridade entre $x_i$ e $x_j$ é escrita como a probabilidade condicional $p_{j|i}$ de que $x_i$ escolheria $x_j$ como vizinho, se os vizinhos fossem sorteados proporcionalmente a uma gaussiana centrada em $x_i$:
#
# $$
# p_{j|i} = \frac{\exp(-\|x_i - x_j\|^2 / 2\sigma_i^2)}{\sum_{k \neq i} \exp(-\|x_i - x_k\|^2 / 2\sigma_i^2)}
# $$
#
# Cada ponto tem a sua própria largura $\sigma_i$. Isso é essencial: em uma região densa, um $\sigma$ pequeno já engloba dezenas de vizinhos; em uma região esparsa, o mesmo $\sigma$ deixaria a distribuição concentrada em um único ponto. O t-SNE escolhe $\sigma_i$ de modo que a entropia da distribuição $P_i$ seja a mesma para todos os pontos. Essa entropia é expressa pela **perplexidade**:
#
# $$
# \text{Perp}(P_i) = 2^{H(P_i)}, \qquad H(P_i) = -\sum_j p_{j|i} \log_2 p_{j|i}
# $$
#
# A perplexidade é aproximadamente o número efetivo de vizinhos que cada ponto enxerga, e é o principal hiperparâmetro do método. Como $H(P_i)$ cresce monotonicamente com $\sigma_i$, o valor certo é encontrado por busca binária sobre $\beta_i = 1 / 2\sigma_i^2$.
#
# As probabilidades condicionais são então simetrizadas em uma distribuição conjunta:
#
# $$
# p_{ij} = \frac{p_{j|i} + p_{i|j}}{2n}
# $$
#
# A simetrização garante que nenhum ponto seja ignorado pela função de custo: mesmo um outlier, que tem $p_{j|i}$ baixo para todo $j$, aparece com peso em $p_{ij}$ através da contribuição dos seus vizinhos.

# %% [markdown]
# ### Similaridades no Mapa
#
# No mapa de baixa dimensão, o t-SNE não usa uma gaussiana, e sim uma distribuição t de Student com um grau de liberdade, equivalente a uma Cauchy:
#
# $$
# q_{ij} = \frac{(1 + \|y_i - y_j\|^2)^{-1}}{\sum_{k \neq l} (1 + \|y_k - y_l\|^2)^{-1}}
# $$
#
# A motivação é o **problema de aglomeração** (*crowding*). Em dimensão alta cabem muito mais pontos mutuamente distantes do que em duas dimensões: o volume disponível a uma distância $r$ cresce com $r^d$, então um ponto pode ter muitos vizinhos a distância moderada sem que eles fiquem próximos entre si. Ao tentar reproduzir essas distâncias em 2D com uma gaussiana, todos os pontos moderadamente distantes acabam empilhados no centro do mapa. A cauda pesada da t de Student resolve isso: para produzir um mesmo valor baixo de $q_{ij}$, ela exige uma distância bem maior do que a gaussiana exigiria, o que empurra os pontos dissimilares para longe e libera espaço.

# %% [markdown]
# ### Otimização
#
# O custo é a divergência de Kullback-Leibler entre as duas distribuições:
#
# $$
# C = \text{KL}(P \| Q) = \sum_i \sum_{j \neq i} p_{ij} \log \frac{p_{ij}}{q_{ij}}
# $$
#
# Essa divergência é assimétrica, e a assimetria tem consequência prática. O termo $p_{ij} \log (p_{ij}/q_{ij})$ é grande quando $p_{ij}$ é alto e $q_{ij}$ é baixo, isto é, quando dois pontos vizinhos no espaço original ficaram longe no mapa. O caso oposto, $p_{ij}$ baixo e $q_{ij}$ alto, quase não é penalizado porque o fator $p_{ij}$ na frente é pequeno. O t-SNE portanto se esforça muito para não separar vizinhos e se esforça pouco para não aproximar estranhos. É por isso que ele preserva estrutura local e não global.
#
# O gradiente tem forma fechada simples:
#
# $$
# \frac{\partial C}{\partial y_i} = 4 \sum_{j} (p_{ij} - q_{ij})\,(1 + \|y_i - y_j\|^2)^{-1}\,(y_i - y_j)
# $$
#
# Cada termo é um vetor na direção $y_i - y_j$. Quando $p_{ij} > q_{ij}$ ele atrai $y_i$ para $y_j$; quando $p_{ij} < q_{ij}$ ele repele. O mapa é o equilíbrio dessas forças.
#
# Duas heurísticas do artigo original são necessárias para que a otimização funcione. A primeira é o **exagero inicial** (*early exaggeration*): nas primeiras centenas de iterações, $P$ é multiplicado por um fator, tipicamente 4 ou 12. Como $Q$ continua somando 1, nenhum $q_{ij}$ consegue acompanhar os $p_{ij}$ inflados, e a atração domina, de modo que os clusters se compactam e ganham espaço vazio entre si antes que a repulsão comece a organizar o layout fino. A segunda é o **momento**, que acumula o gradiente entre iterações, acelerando a convergência e ajudando a escapar de configurações ruins.

# %% [markdown]
# ## Implementação
#
# A busca binária ajusta $\beta_i = 1/2\sigma_i^2$ para atingir a perplexidade pedida. Trabalhamos com a entropia em nats e comparamos com $\log(\text{perplexidade})$, o que é equivalente a comparar $2^H$ com a perplexidade em bits e evita uma troca de base.

# %%
def _conditional_p(D_row, log_perp, tol=1e-5, max_iter=50):
    """Busca binária do beta que faz a linha ter a entropia pedida."""
    beta, lo, hi = 1.0, -np.inf, np.inf

    for _ in range(max_iter):
        P = np.exp(-D_row * beta)
        sum_P = max(P.sum(), 1e-12)
        # H = log(sum P) + beta * <D>_P, forma estável da entropia de Shannon
        H = np.log(sum_P) + beta * np.sum(D_row * P) / sum_P
        diff = H - log_perp
        if abs(diff) < tol:
            break
        if diff > 0:          # entropia alta demais: gaussiana larga demais
            lo = beta
            beta = beta * 2 if hi == np.inf else (beta + hi) / 2
        else:
            hi = beta
            beta = beta / 2 if lo == -np.inf else (beta + lo) / 2

    return P / sum_P

# %%
class TSNE:
    def __init__(self, n_components=2, perplexity=30.0, lr=200.0, n_iter=1000,
                 early_exaggeration=4.0, n_iter_exaggeration=250, random_state=None):
        self.n_components = n_components
        self.perplexity = perplexity
        self.lr = lr
        self.n_iter = n_iter
        self.early_exaggeration = early_exaggeration
        self.n_iter_exaggeration = n_iter_exaggeration
        self.random_state = random_state

    def _joint_p(self, X):
        """Matriz P simétrica das afinidades no espaço original."""
        D = squareform(pdist(X, 'sqeuclidean'))
        n = X.shape[0]
        P = np.zeros((n, n))
        log_perp = np.log(self.perplexity)

        for i in range(n):
            others = np.concatenate((np.arange(i), np.arange(i + 1, n)))
            P[i, others] = _conditional_p(D[i, others], log_perp)

        P = (P + P.T) / (2 * n)
        return np.maximum(P, 1e-12)

    def fit_transform(self, X):
        n = X.shape[0]
        P = self._joint_p(X)

        rng = np.random.default_rng(self.random_state)
        Y = rng.normal(0, 1e-4, (n, self.n_components))
        update = np.zeros_like(Y)
        self.cost_history_ = []

        for it in range(self.n_iter):
            exaggeration = self.early_exaggeration if it < self.n_iter_exaggeration else 1.0
            momentum = 0.5 if it < self.n_iter_exaggeration else 0.8

            # Afinidades no mapa: t de Student com 1 grau de liberdade
            num = 1.0 / (1.0 + squareform(pdist(Y, 'sqeuclidean')))
            np.fill_diagonal(num, 0.0)
            Q = np.maximum(num / num.sum(), 1e-12)

            # Gradiente completo, calculado antes de qualquer atualização
            PQ = (P * exaggeration - Q) * num
            grad = 4.0 * ((np.diag(PQ.sum(axis=1)) - PQ) @ Y)

            update = momentum * update - self.lr * grad
            Y += update
            Y -= Y.mean(axis=0)

            self.cost_history_.append(np.sum(P * np.log(P / Q)))

        self.kl_divergence_ = self.cost_history_[-1]
        return Y

# %% [markdown]
# O gradiente é calculado inteiro e só então aplicado. Atualizar `Y[i]` dentro do laço sobre `i`, usando posições já modificadas para calcular os termos seguintes, transformaria a descida de gradiente em uma iteração ao estilo Gauss-Seidel cujo resultado depende da ordem das amostras.
#
# A expressão `(np.diag(PQ.sum(axis=1)) - PQ) @ Y` é a forma matricial do somatório do gradiente: para cada $i$, ela produz $\sum_j \text{PQ}_{ij}(y_i - y_j)$ de uma vez, sem laço em Python.

# %% [markdown]
# ## Dataset Sintético
#
# Cinco grupos em 20 dimensões, com desvio padrão alto o bastante para que eles se sobreponham parcialmente em qualquer par de eixos originais.

# %%
X, y = make_blobs(n_samples=300, n_features=20, centers=5,
                  cluster_std=5.0, random_state=42)
X = StandardScaler().fit_transform(X)

print(f"X: {X.shape}, {len(np.unique(y))} grupos")

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4.5))
for ax, (a, b) in zip(axes, [(0, 1), (2, 3), (4, 5)]):
    ax.scatter(X[:, a], X[:, b], c=y, cmap='tab10', s=25, alpha=0.8)
    ax.set(xlabel=f'feature {a}', ylabel=f'feature {b}')
fig.suptitle('Pares de features originais')
plt.tight_layout()
plt.show()

# %% [markdown]
# Nenhum par de eixos separa os cinco grupos. A informação que os distingue está espalhada pelas 20 dimensões, não concentrada em duas delas.

# %% [markdown]
# ### Aplicando a Implementação

# %%
tsne = TSNE(n_components=2, perplexity=30.0, lr=200.0, n_iter=1000, random_state=42)
X_tsne = tsne.fit_transform(X)

print(f"KL final: {tsne.kl_divergence_:.4f}")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

ax1.plot(tsne.cost_history_)
ax1.axvline(250, color='crimson', ls='--', label='fim do exagero inicial')
ax1.set(xlabel='iteração', ylabel='KL(P||Q)', title='Convergência')
ax1.legend()

sc = ax2.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='tab10', s=30)
ax2.set(xlabel='componente 1', ylabel='componente 2', title='t-SNE (implementação própria)')
plt.tight_layout()
plt.show()

# %% [markdown]
# A curva de custo tem um degrau nítido na iteração 250. Durante o exagero inicial o KL é medido contra o $P$ verdadeiro, mas a otimização está minimizando um objetivo inflado, então o valor fica em torno de 1,44; assim que o fator cai para 1, o custo desaba para cerca de 0,54 e depois refina lentamente até 0,512. Os cinco grupos aparecem completamente separados no mapa, com espaço vazio entre eles.

# %% [markdown]
# ## O t-SNE do Scikit-Learn
#
# A implementação da biblioteca usa aproximação de Barnes-Hut para o termo de repulsão, vizinhos aproximados para construir $P$ e inicialização por PCA por padrão. Os parâmetros principais são:
#
# - `perplexity`: número efetivo de vizinhos. O padrão é 30.
# - `n_components`: dimensão do mapa. Acima de 3 a aproximação de Barnes-Hut não se aplica e o método fica proibitivo.
# - `init`: `'pca'` (padrão) ou `'random'`. A inicialização por PCA é determinística e preserva melhor a estrutura global.
# - `learning_rate`: `'auto'` por padrão, equivalente a `n_samples / early_exaggeration`.
# - `random_state`: fixa a semente. Sem ele, cada execução produz um mapa diferente.
#
# O atributo `kl_divergence_` guarda o custo final, que é o único número comparável entre execuções.

# %%
sk_tsne = SklearnTSNE(n_components=2, perplexity=30.0, init='pca', random_state=42)
X_sk = sk_tsne.fit_transform(X)

print(f"KL nossa implementação: {tsne.kl_divergence_:.4f}")
print(f"KL scikit-learn:        {sk_tsne.kl_divergence_:.4f}")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))
for ax, Z, title in [(ax1, X_tsne, 'Implementação própria'), (ax2, X_sk, 'Scikit-Learn')]:
    ax.scatter(Z[:, 0], Z[:, 1], c=y, cmap='tab10', s=30)
    ax.set(title=title, xlabel='componente 1', ylabel='componente 2')
plt.tight_layout()
plt.show()

# %% [markdown]
# Os dois mapas custam praticamente o mesmo, 0,512 contra 0,505, e ambos isolam os cinco grupos. As posições e orientações são diferentes, e não há por que não serem: o custo depende apenas das distâncias entre pontos, então qualquer rotação, reflexão ou translação do mapa tem exatamente o mesmo KL. Comparar dois resultados de t-SNE ponto a ponto não faz sentido; o que se compara é quais pontos ficaram juntos.

# %% [markdown]
# ## Perplexidade
#
# A perplexidade define quantos vizinhos cada ponto leva em conta. Valores baixos privilegiam vizinhança imediata e tendem a fragmentar os grupos; valores altos aproximam o método de uma preservação mais global e podem fundir grupos vizinhos.

# %%
perplexities = [5, 30, 100]
fig, axes = plt.subplots(1, 3, figsize=(15, 4.5))

for ax, perp in zip(axes, perplexities):
    model = TSNE(perplexity=perp, n_iter=1000, random_state=42)
    Z = model.fit_transform(X)
    ax.scatter(Z[:, 0], Z[:, 1], c=y, cmap='tab10', s=25)
    ax.set(title=f'perplexity={perp}  (KL={model.kl_divergence_:.3f})')

plt.tight_layout()
plt.show()

# %% [markdown]
# O KL cai de 0,850 para 0,512 e depois para 0,192 conforme a perplexidade sobe, mas isso **não** significa que perplexidade 100 produziu o melhor mapa. Com mais vizinhos, $P$ fica mais espalhada e mais fácil de imitar em duas dimensões; o custo mínimo alcançável é menor por construção. Comparar KL entre perplexidades diferentes é comparar problemas diferentes. O KL só é informativo entre execuções com a mesma perplexidade e os mesmos dados.
#
# Note também que a escala do mapa muda: a extensão total cai de cerca de 85 unidades com perplexidade 5 para 10 unidades com perplexidade 100. Os eixos do t-SNE não têm unidade nem significado fixo.

# %% [markdown]
# ## Como (Não) Ler um Gráfico t-SNE
#
# Duas propriedades que a intuição de gráfico de dispersão sugere, e que o t-SNE não garante: o tamanho aparente de um cluster e a distância entre clusters. Construímos um caso onde a resposta correta é conhecida.

# %%
rng = np.random.default_rng(0)
A = rng.normal(0, 0.5, (100, 2))
B = rng.normal(0, 5.0, (100, 2)) + [40, 0]
C = rng.normal(0, 0.5, (100, 2)) + [200, 0]

Z_raw = np.vstack([A, B, C])
labels = np.repeat([0, 1, 2], 100)
Z_tsne = SklearnTSNE(n_components=2, perplexity=30, init='pca',
                     random_state=42).fit_transform(Z_raw)


def group_stats(Z, labels):
    """Raio médio de cada grupo e distâncias entre os centróides."""
    centers = np.array([Z[labels == k].mean(axis=0) for k in range(3)])
    radii = [np.linalg.norm(Z[labels == k] - centers[k], axis=1).mean() for k in range(3)]
    return radii, centers


for name, Z in [('original', Z_raw), ('t-SNE', Z_tsne)]:
    radii, centers = group_stats(Z, labels)
    print(f"{name:>8}  raios A/B/C: {radii[0]:5.2f} {radii[1]:5.2f} {radii[2]:5.2f}"
          f"   dist A-B: {np.linalg.norm(centers[0] - centers[1]):6.2f}"
          f"   dist B-C: {np.linalg.norm(centers[1] - centers[2]):6.2f}")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))
for ax, Z, title in [(ax1, Z_raw, 'Dados originais'), (ax2, Z_tsne, 't-SNE')]:
    ax.scatter(Z[:, 0], Z[:, 1], c=labels, cmap='tab10', s=25)
    ax.set_title(title)
    ax.set_aspect('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# Nos dados originais, o grupo B é dez vezes mais disperso que A e C (raio médio 6,32 contra 0,61 e 0,62), e C está quatro vezes mais longe de B do que A está (160,6 contra 39,4). No mapa t-SNE, os três grupos têm praticamente o mesmo raio (3,85, 3,90 e 4,17) e as duas distâncias entre centróides ficam quase idênticas (37,6 e 37,4).
#
# A causa é o $\sigma_i$ adaptativo. Como cada ponto ajusta a sua largura para enxergar aproximadamente `perplexity` vizinhos, a densidade local é normalizada antes de a otimização começar: um grupo disperso e um grupo compacto produzem matrizes $P$ indistinguíveis. E como o KL quase não penaliza aproximar pontos distantes, nada obriga o mapa a manter B e C mais afastados do que A e B.
#
# Na prática, num gráfico t-SNE apenas **quais pontos estão juntos** é informação confiável. O tamanho de um aglomerado não indica dispersão nos dados originais, a distância entre dois aglomerados não indica o quão diferentes eles são, e o espaço vazio entre grupos é em boa parte artefato do exagero inicial. Aglomerados que aparecem com perplexidade baixa podem ainda ser subdivisões espúrias, então convém repetir com valores diferentes de `perplexity` e de `random_state` antes de concluir qualquer coisa.

# %% [markdown]
# ## Aplicação: Dígitos Manuscritos
#
# O dataset `digits` tem 1797 imagens de 8×8 pixels, ou seja, 64 dimensões, com dez classes. Comparamos a projeção linear do PCA com o t-SNE.

# %%
digits = load_digits()
X_digits = StandardScaler().fit_transform(digits.data)
y_digits = digits.target

print(f"X: {X_digits.shape}, {len(np.unique(y_digits))} classes")

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_digits)
X_tsne_digits = SklearnTSNE(n_components=2, perplexity=30, init='pca',
                            random_state=42).fit_transform(X_digits)

print(f"Variância explicada pelas 2 componentes do PCA: {pca.explained_variance_ratio_.sum():.2%}")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
for ax, Z, title in [(ax1, X_pca, 'PCA (2 componentes)'),
                     (ax2, X_tsne_digits, 't-SNE (perplexity=30)')]:
    sc = ax.scatter(Z[:, 0], Z[:, 1], c=y_digits, cmap='tab10', s=10)
    ax.set(title=title, xticks=[], yticks=[])
fig.colorbar(sc, ax=[ax1, ax2], label='dígito', ticks=range(10))
plt.show()

# %% [markdown]
# Para quantificar quanto de estrutura cada projeção preserva, medimos a acurácia de um k-NN treinado sobre as coordenadas de duas dimensões. É uma medida direta de organização local: se vizinhos no mapa têm o mesmo rótulo, a vizinhança foi preservada.

# %%
knn = KNeighborsClassifier(n_neighbors=5)
for name, Z in [('64 dimensões originais', X_digits),
                ('PCA (2D)', X_pca),
                ('t-SNE (2D)', X_tsne_digits)]:
    acc = cross_val_score(knn, Z, y_digits, cv=5).mean()
    print(f"{name:>22}: {acc:.4f}")

# %% [markdown]
# O PCA em duas componentes retém apenas 21,6% da variância e o k-NN cai para 51,4%. O t-SNE, com as mesmas duas dimensões, chega a 95,4%, acima até dos 94,4% obtidos nas 64 dimensões originais.
#
# Esse último número merece cuidado. O t-SNE não é um método de extração de features que melhora classificação: ele **viu os dados inteiros** ao construir $P$ e organizou o mapa de forma a agrupar vizinhos, o que é exatamente o que o k-NN mede. A acurácia alta confirma que a estrutura de vizinhança foi preservada, não que a projeção seja útil como pré-processamento para um classificador.

# %% [markdown]
# ## Custo e Limitações
#
# O custo por iteração da formulação exata é $O(n^2)$, tanto em tempo quanto em memória, porque a matriz de afinidades é densa. A aproximação de Barnes-Hut, usada pelo scikit-learn, reduz o termo de repulsão para $O(n \log n)$ agrupando pontos distantes, mas a construção de $P$ ainda exige uma busca de vizinhos. Na prática o t-SNE é confortável até dezenas de milhares de pontos e desconfortável acima disso.

# %%
import time

for n in [200, 400, 800]:
    X_n, _ = make_blobs(n_samples=n, n_features=20, centers=5,
                        cluster_std=5.0, random_state=42)
    X_n = StandardScaler().fit_transform(X_n)
    t0 = time.perf_counter()
    TSNE(n_iter=300, random_state=42).fit_transform(X_n)
    print(f"n={n:4d}: {time.perf_counter() - t0:.2f}s")

# %% [markdown]
# Dobrar o número de amostras multiplica o tempo por aproximadamente quatro, o comportamento quadrático esperado.
#
# A limitação mais restritiva é que **não há `transform`**. O t-SNE otimiza as posições dos pontos que recebeu, e não existe função aprendida para projetar dados novos: incluir uma amostra nova exige rodar tudo de novo. Pela mesma razão, ele é uma ferramenta de visualização, e usar o embedding de duas dimensões como entrada de um modelo descarta informação de forma não controlada e não generaliza.
#
# Os eixos, por sua vez, não significam nada. Não são combinações de features, não têm unidade e não são ordenados por importância, de modo que não existe equivalente ao `explained_variance_ratio_` do PCA. O resultado também depende da semente: sem `random_state` fixo, cada execução produz um mapa diferente, e diferenças visuais entre execuções não são diferenças nos dados.
#
# Por fim, a distância euclidiana em dimensão muito alta é pouco informativa. É prática comum reduzir para algumas dezenas de dimensões com PCA antes de aplicar o t-SNE, o que também acelera bastante o cálculo de $P$.

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercício 1: Sensibilidade à Semente
#
# Rode a implementação própria sobre o dataset sintético com quatro valores diferentes de `random_state`, mantendo todos os demais parâmetros fixos, e plote os quatro mapas lado a lado com o KL final de cada um no título. Os KLs são parecidos? E os mapas? Escreva o que essa comparação diz sobre interpretar a posição de um cluster em um gráfico t-SNE.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 2: Wine
#
# Carregue o dataset Wine com `sklearn.datasets.load_wine`, padronize as features e projete em duas dimensões com PCA e com t-SNE. Compare visualmente a separação das três classes e meça a acurácia de um k-NN sobre cada projeção, como foi feito com os dígitos. Wine tem 13 features e 178 amostras; discuta se o t-SNE é a escolha adequada nessa escala.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 3: O Efeito do Exagero Inicial
#
# Modifique a chamada da implementação própria para desligar o exagero inicial (`early_exaggeration=1.0`) e compare com o resultado padrão: plote os dois mapas e as duas curvas de custo. O KL final ficou melhor ou pior sem o exagero? A separação visual entre os grupos mudou? Relacione a resposta com o papel que o exagero desempenha na fase inicial da otimização.

# %%
# Seu código aqui
