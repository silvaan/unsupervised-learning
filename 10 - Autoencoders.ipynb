# %% [markdown]
# # Autoencoders
#
# Um autoencoder é uma rede neural treinada para reproduzir a própria entrada, com a restrição de que a informação precisa atravessar uma camada intermediária de dimensão bem menor. Essa camada, o gargalo, é o objeto de interesse: para conseguir reconstruir os dados a partir dela, a rede é obrigada a descobrir sozinha quais características são essenciais e quais podem ser descartadas. O treinamento é inteiramente não supervisionado, já que o rótulo de cada amostra é ela mesma.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

torch.manual_seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"dispositivo: {device}")

# %% [markdown]
# ## Fundamentação Matemática
#
# O modelo é a composição de duas funções parametrizadas:
#
# - **Codificador** $f_\theta: \mathbb{R}^D \to \mathbb{R}^m$, que leva a entrada $\mathbf{x}$ ao código latente $\mathbf{z} = f_\theta(\mathbf{x})$;
# - **Decodificador** $g_\phi: \mathbb{R}^m \to \mathbb{R}^D$, que devolve a reconstrução $\hat{\mathbf{x}} = g_\phi(\mathbf{z})$.
#
# Com $m \ll D$, treina-se minimizando o erro de reconstrução sobre o conjunto de dados:
#
# $$
# \mathcal{L}(\theta, \phi) = \frac{1}{N}\sum_{i=1}^{N} \left\| \mathbf{x}^{(i)} - g_\phi\!\left(f_\theta(\mathbf{x}^{(i)})\right) \right\|^2
# $$
#
# A restrição $m \ll D$ é o que dá sentido ao problema. Sem ela, a solução ótima seria a identidade, e a rede não aprenderia nada sobre os dados.
#
# ### A Relação com o PCA
#
# Um caso vale ser isolado. Se $f_\theta$ e $g_\phi$ forem transformações afins, ou seja, camadas lineares sem função de ativação, o autoencoder é
#
# $$
# \hat{\mathbf{x}} = W_d (W_e \mathbf{x} + b_e) + b_d
# $$
#
# e minimizar o erro quadrático sobre essa família tem solução conhecida. O subespaço de dimensão $m$ que minimiza o erro quadrático de reconstrução é exatamente o gerado pelas $m$ primeiras componentes principais dos dados. Um autoencoder linear treinado até a convergência não pode fazer melhor que o PCA, e no ótimo faz igual.
#
# A diferença é que o autoencoder não recupera as componentes principais *individualmente*: qualquer base do mesmo subespaço dá o mesmo erro, então as colunas de $W_d$ são uma combinação arbitrária das componentes, sem ordenação por variância e sem ortogonalidade garantida.
#
# O interesse dos autoencoders começa, portanto, exatamente onde a linearidade termina. Com funções de ativação não lineares entre as camadas, $f_\theta$ e $g_\phi$ deixam de estar restritos a subespaços e podem se ajustar a variedades curvas.

# %% [markdown]
# ## Preparação dos Dados
#
# O MNIST tem 70 mil imagens de dígitos manuscritos em tons de cinza, de 28×28 pixels, o que dá vetores de $D = 784$ dimensões com valores em $[0, 1]$. Usamos 10 mil imagens para treino e mil para validação, o suficiente para os experimentos e rápido o bastante para rodar sem GPU.

# %%
train_data = datasets.MNIST('./data', train=True, download=True, transform=transforms.ToTensor())
test_data = datasets.MNIST('./data', train=False, download=True, transform=transforms.ToTensor())

train_set = Subset(train_data, range(10_000))
val_set = Subset(test_data, range(1_000))

# versões achatadas em memória, usadas nas comparações com o PCA
X_train = torch.stack([x.view(-1) for x, _ in train_set])
X_val = torch.stack([x.view(-1) for x, _ in val_set])
y_val = np.array([label for _, label in val_set])

train_loader = DataLoader(train_set, batch_size=128, shuffle=True,
                          generator=torch.Generator().manual_seed(42))

print(f"treino: {tuple(X_train.shape)}   validação: {tuple(X_val.shape)}")

# %% [markdown]
# ## Implementação
#
# Uma única classe cobre os dois casos. Com `hidden=None` o codificador e o decodificador são camadas lineares simples; com uma lista de larguras, ficam profundos e com ativações ReLU. A saída passa por uma sigmoide no caso não linear porque os pixels estão em $[0, 1]$.

# %%
class Autoencoder(nn.Module):
    def __init__(self, latent_dim=16, hidden=(128, 64), input_dim=784):
        super().__init__()
        if hidden is None:
            self.encoder = nn.Linear(input_dim, latent_dim)
            self.decoder = nn.Linear(latent_dim, input_dim)
            return

        widths = [input_dim, *hidden]
        encoder_layers = []
        for a, b in zip(widths, widths[1:]):
            encoder_layers += [nn.Linear(a, b), nn.ReLU()]
        self.encoder = nn.Sequential(*encoder_layers, nn.Linear(widths[-1], latent_dim))

        widths = [latent_dim, *reversed(hidden)]
        decoder_layers = []
        for a, b in zip(widths, widths[1:]):
            decoder_layers += [nn.Linear(a, b), nn.ReLU()]
        self.decoder = nn.Sequential(*decoder_layers, nn.Linear(widths[-1], input_dim), nn.Sigmoid())

    def forward(self, x):
        return self.decoder(self.encoder(x))

# %%
def train(model, loader, epochs=30, lr=1e-3, noise=0.0, seed=42):
    """Treina minimizando o MSE entre a saída e a imagem limpa."""
    torch.manual_seed(seed)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()
    history = []

    model.train()
    for epoch in range(epochs):
        total = 0.0
        for images, _ in loader:
            clean = images.view(images.size(0), -1).to(device)
            # no denoising a entrada é corrompida, mas o alvo continua sendo a imagem limpa
            corrupted = torch.clamp(clean + noise * torch.randn_like(clean), 0, 1) if noise else clean

            loss = criterion(model(corrupted), clean)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total += loss.item()

        history.append(total / len(loader))
    return history


def reconstruction_mse(model, X, noise=0.0, seed=0):
    """MSE de reconstrução da imagem limpa a partir de uma entrada possivelmente ruidosa."""
    model.eval()
    torch.manual_seed(seed)
    with torch.no_grad():
        X = X.to(device)
        corrupted = torch.clamp(X + noise * torch.randn_like(X), 0, 1) if noise else X
        return nn.MSELoss()(model(corrupted), X).item()

# %% [markdown]
# ## O Autoencoder Linear é o PCA
#
# Antes de qualquer coisa não linear, vale confirmar experimentalmente a equivalência anunciada na fundamentação. Treinamos um autoencoder puramente linear com 16 dimensões latentes e comparamos com o PCA de 16 componentes em duas frentes: o erro de reconstrução e o subespaço aprendido.
#
# A comparação de subespaços usa os **ângulos principais**. Dadas duas bases ortonormais $Q_1$ e $Q_2$ dos dois subespaços, os valores singulares de $Q_1^\top Q_2$ são os cossenos desses ângulos. Todos iguais a 1 significa que os subespaços coincidem, independentemente de as bases serem diferentes.

# %%
linear_ae = Autoencoder(latent_dim=16, hidden=None).to(device)
train(linear_ae, train_loader, epochs=40, lr=3e-3)

pca = PCA(n_components=16).fit(X_train.numpy())
X_pca = pca.inverse_transform(pca.transform(X_val.numpy()))

print(f"MSE autoencoder linear: {reconstruction_mse(linear_ae, X_val):.5f}")
print(f"MSE PCA (16 componentes): {((X_val.numpy() - X_pca) ** 2).mean():.5f}")

# O subespaço de reconstrução é o espaço-coluna dos pesos do decodificador.
decoder_basis = np.linalg.qr(linear_ae.decoder.weight.detach().cpu().numpy())[0]
pca_basis = np.linalg.qr(pca.components_.T)[0]
cosines = np.linalg.svd(decoder_basis.T @ pca_basis, compute_uv=False)

print(f"\ncossenos dos ângulos principais: mínimo={cosines.min():.4f}, média={cosines.mean():.4f}")

# %% [markdown]
# Os dois erros coincidem até a quarta casa, 0,02745 contra 0,02738, e o menor cosseno entre os subespaços é 0,9994. O autoencoder linear encontrou o mesmo subespaço de 16 dimensões que o PCA, partindo de pesos aleatórios e sem calcular nenhum autovetor.
#
# Isso também estabelece o padrão de comparação para o resto do notebook: **qualquer ganho de um autoencoder sobre o PCA na mesma dimensão latente vem da não linearidade**, não da arquitetura em si.

# %% [markdown]
# ## O Autoencoder Não Linear
#
# Agora com camadas intermediárias de 128 e 64 unidades e ativações ReLU, treinado para várias dimensões de gargalo e comparado ao PCA na mesma dimensão.

# %%
results = []
for latent_dim in [2, 4, 8, 16, 32]:
    model = Autoencoder(latent_dim=latent_dim).to(device)
    train(model, train_loader, epochs=30)

    pca_k = PCA(n_components=latent_dim).fit(X_train.numpy())
    X_rec = pca_k.inverse_transform(pca_k.transform(X_val.numpy()))
    results.append((latent_dim, reconstruction_mse(model, X_val),
                    ((X_val.numpy() - X_rec) ** 2).mean(),
                    pca_k.explained_variance_ratio_.sum()))
    if latent_dim == 16:
        ae_model = model

print(f"{'m':>4} {'MSE autoencoder':>17} {'MSE PCA':>10} {'variância PCA':>15}")
for latent_dim, ae_mse, pca_mse, variance in results:
    print(f"{latent_dim:>4} {ae_mse:>17.5f} {pca_mse:>10.5f} {variance:>14.1%}")

# %%
dims, ae_mses, pca_mses, _ = zip(*results)
plt.figure(figsize=(8, 5))
plt.plot(dims, ae_mses, 'o-', label='autoencoder (ReLU)')
plt.plot(dims, pca_mses, 's--', label='PCA')
plt.xscale('log', base=2)
plt.xticks(dims, dims)
plt.xlabel('dimensão latente $m$')
plt.ylabel('MSE de reconstrução (validação)')
plt.legend()
plt.title('Erro de reconstrução em função do gargalo')
plt.show()

# %% [markdown]
# A vantagem da não linearidade é maior justamente onde o gargalo é mais apertado. Com $m = 2$, o autoencoder chega a 0,04406 contra 0,05474 do PCA, uma redução de 20%; com $m = 8$ a diferença é de 35%, a maior da tabela.
#
# Em $m = 32$ a ordem se inverte: 0,01980 contra 0,01749 do PCA. Não é contradição com o resultado anterior, porque o PCA é ótimo entre projeções lineares e nada impede que uma rede não linear treinada por 30 épocas de gradiente descendente fique abaixo desse ótimo. Com 32 dimensões o PCA já retém 74,9% da variância e reconstrói bem; o autoencoder deixa de ser limitado pela capacidade e passa a ser limitado pela otimização.

# %% [markdown]
# ## Reconstruções

# %%
ae_model.eval()
with torch.no_grad():
    originals = X_val[:10].to(device)
    reconstructions = ae_model(originals).cpu().numpy().reshape(-1, 28, 28)
X_pca_10 = X_pca[:10].reshape(-1, 28, 28)

fig, axes = plt.subplots(3, 10, figsize=(15, 5))
rows = [(originals.cpu().numpy().reshape(-1, 28, 28), 'original'),
        (X_pca_10, 'PCA (16)'),
        (reconstructions, 'autoencoder (16)')]
for row, (images, label) in zip(axes, rows):
    row[0].set_ylabel(label, fontsize=10)
    for ax, image in zip(row, images):
        ax.imshow(image, cmap='gray', vmin=0, vmax=1)
        ax.set(xticks=[], yticks=[])
plt.tight_layout()
plt.show()

# %% [markdown]
# As duas reconstruções preservam a identidade dos dígitos, mas erram de formas diferentes. O PCA produz traços borrados e um fundo salpicado de cinza, porque a reconstrução é uma soma de 16 imagens fixas com pesos que podem ser negativos e nada garante que o resultado fique em $[0, 1]$. O autoencoder produz traços mais limpos e fundo escuro, em parte pela sigmoide de saída e em parte porque aprendeu que o fundo do MNIST é sempre preto.

# %% [markdown]
# ## O Espaço Latente
#
# A camada de gargalo tem 16 dimensões, então visualizá-la exige uma segunda redução. Antes disso, uma medida direta: se o código latente preservou a informação que distingue os dígitos, um classificador simples deve funcionar sobre ele.

# %%
with torch.no_grad():
    Z_ae = ae_model.encoder(X_val.to(device)).cpu().numpy()
Z_pca = pca.transform(X_val.numpy())

knn = KNeighborsClassifier(n_neighbors=5)
for name, Z in [('784 pixels originais', X_val.numpy()), ('PCA (16)', Z_pca), ('autoencoder (16)', Z_ae)]:
    print(f"{name:>22}: {cross_val_score(knn, Z, y_val, cv=5).mean():.4f}")

# %%
Z_2d = TSNE(n_components=2, perplexity=30, init='pca', random_state=42).fit_transform(Z_ae)

plt.figure(figsize=(9, 7))
scatter = plt.scatter(Z_2d[:, 0], Z_2d[:, 1], c=y_val, cmap='tab10', s=15)
plt.colorbar(scatter, label='dígito', ticks=range(10))
plt.title('Espaço latente de 16 dimensões, projetado em 2D')
plt.xticks([]); plt.yticks([])
plt.show()

# %% [markdown]
# O k-NN sobre o código latente de 16 dimensões alcança 84,2%, exatamente o mesmo valor obtido nos 784 pixels originais, enquanto as 16 componentes principais chegam a 87,2%. **Comprimir de 784 para 16 dimensões preservou a informação de classe, mas o autoencoder não a organizou melhor que uma projeção linear, e neste caso organizou um pouco pior.** Isso é esperado, já que o treino otimizou reconstrução e não separabilidade, e a métrica euclidiana no espaço latente não tem por que ser mais informativa que no espaço original.
#
# Ainda assim, os dígitos formam grupos separados no espaço latente, embora o autoencoder nunca tenha visto um rótulo: as classes emergem porque imagens do mesmo dígito se parecem, e reconstruí-las bem exige códigos parecidos. Os grupos que se tocam são os previsíveis, ou seja, 4, 7 e 9, que compartilham traços diagonais, e 3, 5 e 8.
#
# O agrupamento é uma consequência da tarefa de reconstrução, não um objetivo. Nada no treino pediu que classes diferentes ficassem separadas, e um autoencoder pode perfeitamente aprender um código excelente para reconstrução no qual as classes se sobrepõem.

# %% [markdown]
# ## Interpolação no Espaço Latente
#
# Um teste de que o espaço latente é contínuo, e não apenas uma tabela de códigos memorizados, é percorrer o segmento entre dois códigos e decodificar os pontos intermediários:
#
# $$
# \mathbf{z}(t) = (1-t)\,\mathbf{z}_1 + t\,\mathbf{z}_2, \qquad t \in [0, 1]
# $$
#
# Se o decodificador produzir dígitos plausíveis ao longo de todo o caminho, é sinal de que a região entre os dois códigos também corresponde a imagens válidas.

# %%
def interpolate(model, x1, x2, steps=9):
    """Decodifica pontos ao longo do segmento entre dois códigos latentes."""
    model.eval()
    with torch.no_grad():
        z1, z2 = model.encoder(torch.stack([x1, x2]).to(device))
        ts = torch.linspace(0, 1, steps, device=device).unsqueeze(1)
        images = model.decoder((1 - ts) * z1 + ts * z2)
    return images.cpu().numpy().reshape(-1, 28, 28)


pairs = [(0, np.where(y_val != y_val[0])[0][0]), (1, np.where(y_val == y_val[1])[0][1])]

fig, axes = plt.subplots(len(pairs), 9, figsize=(15, 2 + 2 * len(pairs)))
for row, (i, j) in zip(axes, pairs):
    for ax, image in zip(row, interpolate(ae_model, X_val[i], X_val[j])):
        ax.imshow(image, cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    row[0].set_title(f'{y_val[i]}', fontsize=11)
    row[-1].set_title(f'{y_val[j]}', fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# Na segunda linha, entre dois exemplares do mesmo dígito, todos os quadros intermediários são dígitos legítimos, e a transformação é uma deformação contínua de um traço no outro. Na primeira, entre dígitos diferentes, os quadros do meio são formas ambíguas que não pertencem a nenhuma classe.
#
# Isso não é defeito do modelo. Um autoencoder comum só é treinado a reconstruir os pontos que viu, e nada no seu objetivo exige que o segmento entre dois códigos caia sobre a variedade dos dígitos reais. Fazer com que qualquer ponto do espaço latente decodifique em algo plausível exige uma restrição adicional sobre a distribuição dos códigos, que é o que caracteriza os autoencoders variacionais.

# %% [markdown]
# ## Denoising Autoencoders
#
# Uma variação treina a rede a reconstruir a imagem **limpa** a partir de uma versão corrompida. Aplica-se um processo de ruído $\tilde{\mathbf{x}} \sim q(\tilde{\mathbf{x}} \mid \mathbf{x})$, aqui ruído gaussiano aditivo seguido de truncamento em $[0, 1]$, e minimiza-se
#
# $$
# \mathcal{L}_{\text{DAE}} = \frac{1}{N}\sum_{i} \left\| \mathbf{x}^{(i)} - g_\phi\!\left(f_\theta(\tilde{\mathbf{x}}^{(i)})\right) \right\|^2
# $$
#
# O alvo continua sendo a imagem original; só a entrada muda. A consequência é que a identidade deixa de ser solução: copiar a entrada reproduziria o ruído. Para acertar o alvo, a rede precisa aprender onde estão as imagens válidas e projetar a entrada corrompida de volta para essa região. O ruído afasta o ponto da variedade dos dados, e o treinamento ensina o caminho de volta.

# %%
dae_model = Autoencoder(latent_dim=16).to(device)
dae_history = train(dae_model, train_loader, epochs=30, noise=0.4)
ae_history = train(Autoencoder(latent_dim=16).to(device), train_loader, epochs=30)

plt.figure(figsize=(8, 5))
plt.plot(ae_history, label='autoencoder')
plt.plot(dae_history, label='denoising (ruído 0.4)')
plt.xlabel('época')
plt.ylabel('MSE de treino')
plt.legend()
plt.show()

# %%
print(f"{'ruído':>7} {'autoencoder':>13} {'denoising':>11}")
for noise in [0.0, 0.2, 0.4, 0.8]:
    print(f"{noise:>7.1f} {reconstruction_mse(ae_model, X_val, noise):>13.5f} "
          f"{reconstruction_mse(dae_model, X_val, noise):>11.5f}")

# %%
torch.manual_seed(0)
with torch.no_grad():
    clean = X_val[:10].to(device)
    noisy = torch.clamp(clean + 0.4 * torch.randn_like(clean), 0, 1)
    rows = [(clean, 'original'), (noisy, 'com ruído'),
            (ae_model(noisy), 'autoencoder'), (dae_model(noisy), 'denoising')]

fig, axes = plt.subplots(4, 10, figsize=(15, 6.5))
for row, (batch, label) in zip(axes, rows):
    row[0].set_ylabel(label, fontsize=10)
    for ax, image in zip(row, batch.cpu().numpy().reshape(-1, 28, 28)):
        ax.imshow(image, cmap='gray', vmin=0, vmax=1)
        ax.set(xticks=[], yticks=[])
plt.tight_layout()
plt.show()

# %% [markdown]
# A tabela separa as duas coisas que o denoising troca entre si.
#
# Em entradas limpas o autoencoder comum ganha, 0,02051 contra 0,03022, que é exatamente o que ele foi treinado a fazer. A partir de ruído 0,2 a ordem se inverte, e em 0,4 a diferença é de um fator 2,7 (0,02594 contra 0,06914). Em 0,8 chega a 2,8.
#
# O detalhe mais informativo é que o denoising reconstrói **melhor** a partir de entradas com ruído 0,4 (0,02594) do que a partir de entradas limpas (0,03022). Não há mistério: ele foi treinado exclusivamente com entradas nesse nível de corrupção, e a imagem limpa é, para ele, uma entrada fora da distribuição de treino. O modelo não aprendeu "a remover ruído" em abstrato; aprendeu a inverter um processo de corrupção específico.
#
# Nas imagens, o autoencoder comum propaga o ruído para a saída, porque tratá-lo como sinal é o comportamento correto para quem foi treinado a copiar a entrada. O denoising devolve dígitos limpos, ao custo de traços mais grossos e detalhes atenuados, que é o preço de projetar a entrada de volta para a região das imagens plausíveis.

# %% [markdown]
# ## Custo e Limitações
#
# O custo por época é linear no número de amostras e proporcional ao número de parâmetros da rede. Aqui são cerca de 220 mil parâmetros e 30 épocas sobre 10 mil imagens, o que roda em poucos minutos em CPU. Diferentemente do PCA, que tem solução fechada, o resultado depende da inicialização, da taxa de aprendizado, do tamanho do lote e do número de épocas.
#
# Não há solução única nem ordenação. Duas execuções com sementes diferentes produzem espaços latentes diferentes, ambos válidos, e não existe equivalente ao `explained_variance_ratio_`: as coordenadas latentes não são ordenadas por importância nem são independentes entre si. Pela mesma razão, as dimensões latentes não são interpretáveis, e nada garante que uma coordenada corresponda a inclinação, espessura ou qualquer atributo nomeável.
#
# O espaço latente também não é um espaço gerador. Como a interpolação mostrou, pontos que a rede nunca visitou durante o treino podem decodificar em imagens sem sentido.
#
# Vale lembrar ainda que um gargalo estreito não é a única forma de regularização. Um autoencoder com $m$ grande e capacidade suficiente aprende algo próximo da identidade e não extrai representação nenhuma, e o denoising é uma alternativa que restringe o que a rede pode aprender sem depender só da largura do gargalo.
#
# Por fim, duas exigências práticas. O método precisa de mais dados que o PCA, porque com poucas amostras uma rede com centenas de milhares de parâmetros memoriza o conjunto de treino em vez de aprender a estrutura. E é sensível à escala das features: aqui todos os pixels vivem em $[0,1]$, mas com features de escalas diferentes o MSE é dominado pelas de maior amplitude, e a padronização passa a ser necessária.

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercício 1: Gargalo de Duas Dimensões
#
# Treine um autoencoder com `latent_dim=2` e plote diretamente os códigos latentes do conjunto de validação em um gráfico de dispersão colorido pelo dígito, sem passar por nenhuma redução adicional. Compare com a projeção do PCA de duas componentes sobre os mesmos dados. Em seguida, monte uma grade regular de pontos $(z_1, z_2)$ cobrindo a região ocupada e decodifique cada um deles, exibindo o resultado como um mosaico de imagens. Que regiões da grade produzem dígitos reconhecíveis e quais produzem formas sem sentido?

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 2: Nível de Ruído
#
# Treine denoising autoencoders com `noise` igual a 0,1, 0,4 e 0,9 e avalie cada um contra os quatro níveis de ruído da tabela desta seção, montando uma matriz de treino contra teste. Um modelo treinado com ruído forte é melhor em entradas limpas? E um treinado com ruído fraco lida bem com entradas muito corrompidas? Relacione as respostas com o papel do ruído como regularizador.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 3: Detecção de Anomalias
#
# Treine um autoencoder usando apenas as imagens do dígito 1 do conjunto de treino. Em seguida, calcule o erro de reconstrução, imagem a imagem, sobre todo o conjunto de validação, e compare a distribuição dos erros das imagens do dígito 1 com a dos demais dígitos. Escolha um limiar a partir dessas distribuições e reporte quantas imagens de cada classe seriam sinalizadas como anômalas. Que dígitos são mais confundidos com o 1, e por quê?

# %%
# Seu código aqui
